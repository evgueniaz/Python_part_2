# %%
csv #- comma-separated values - данные разделенные запятой
df = pd.read_csv('file.csv', # функция считывания внешнего файла формата csv (можно выбрать необходимый формат)
encoding='windows-1251',
headler=0, # - какую строку считать заголовком(по умолчанию нулевую)
sep = ';',
index_col='название_столбца',
parse_dates=['Date'],
dayfirst=True)
# 'file.csv' - путь к файлу,
# sep - разделитель sep(по умолчаниию ',')
# encoding – параметр в read_csv, отвечает за кодировку текста, которая может быть различной. Самая распространённая – utf
# index_col='название_столбца' - название столбца, который будет выступать как столбец индексов
# index_col=[0] - индекс столбца, который будет выступать как столбец индексов
# parse_dates – указывает, стоит ли воспринимать даты как даты (по умолчанию они воспринимаются пандасом как строки).
# пример pd.read_csv(path, parse_dates=['some_date', 'another_date'])
# Параметр с датами может принимать несколько значений:
# True – пытается перевести в дату первую колонку
# список колонок – parse_dates=['some_date', 'another_date']
# пытается перевести в дату указанные в списке колонки и столбцы create_data, payment_data
# будут обрабатываться как даты
# dayfirst=True - первое значение в дате это день или нет - True/False
# df['Date'].dt.day - номер дня недели в соответствии с данными в колонке с датами !!!!!
# df['Date'].dt.day_name() - название дня недели в соответствии с данными в колонке с датами
# df['Date'].dt.month - номер месяца в соответствии с данными в колонке с датами
# df['Date'].dt.month_name() - название месяца в соответствии с данными в колонке с датами
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 csv #- comma-separated values - данные разделенные запятой
#       2 df = pd.read_csv('file.csv', # функция считывания внешнего файла формата csv (можно выбрать необходимый формат)
#       3 encoding='windows-1251',
#       4 headler=0, # - какую строку считать заголовком(по умолчанию нулевую)
#    (...)
#       7 parse_dates=['Date'],
#       8 dayfirst=True)
#       9 # 'file.csv' - путь к файлу,
#      10 # sep - разделитель sep(по умолчаниию ',')
#      11 # encoding – параметр в read_csv, отвечает за кодировку текста, которая может быть различной. Самая распространённая – utf
#    (...)
#      24 # df['Date'].dt.month - номер месяца в соответствии с данными в колонке с датами
#      25 # df['Date'].dt.month_name() - название месяца в соответствии с данными в колонке с датами
#
# NameError: name 'csv' is not defined

# %% [markdown]
# ## Задание 1.
# 1. Скачать данные по ссылке
# 2. Считать данные с помощью pandas
# 3. Вывести на экран первые 5 строк
# 4. Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd
df = pd.read_csv('laptop_price.csv', encoding='windows-1251', index_col='laptop_ID')
df
# Out:
#           Company                              Product            TypeName  \
# laptop_ID
# 1           Apple                          MacBook Pro           Ultrabook
# 2           Apple                          Macbook Air           Ultrabook
# 3              HP                               250 G6            Notebook
# 4           Apple                          MacBook Pro           Ultrabook
# 5           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1316       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1317       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1318       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1319           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#            Inches                            ScreenResolution  \
# laptop_ID
# 1            13.3          IPS Panel Retina Display 2560x1600
# 2            13.3                                    1440x900
# 3            15.6                           Full HD 1920x1080
# 4            15.4          IPS Panel Retina Display 2880x1800
# 5            13.3          IPS Panel Retina Display 2560x1600
# ...           ...                                         ...
# 1316         14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1317         13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1318         14.0                                    1366x768
# 1319         15.6                                    1366x768
# 1320         15.6                                    1366x768
#
#                                             Cpu   Ram               Memory  \
# laptop_ID
# 1                          Intel Core i5 2.3GHz   8GB            128GB SSD
# 2                          Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3                    Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 4                          Intel Core i7 2.7GHz  16GB            512GB SSD
# 5                          Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                         ...   ...                  ...
# 1316                 Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1317                 Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1318       Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1319                 Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1320       Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                     Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 1          Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 2                Intel HD Graphics 6000       macOS  1.34kg       898.94
# 3                 Intel HD Graphics 620       No OS  1.86kg       575.00
# 4                    AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 5          Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                                 ...         ...     ...          ...
# 1316              Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1317              Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1318                  Intel HD Graphics  Windows 10   1.5kg       229.00
# 1319                 AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1320                  Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 12 columns]

# %%
df.head()
# Out:
#           Company      Product   TypeName  Inches  \
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3
# 2           Apple  Macbook Air  Ultrabook    13.3
# 3              HP       250 G6   Notebook    15.6
# 4           Apple  MacBook Pro  Ultrabook    15.4
# 5           Apple  MacBook Pro  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 3                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 4          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 5          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
#
#             Ram               Memory                           Gpu  OpSys  \
# laptop_ID
# 1           8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS
# 2           8GB  128GB Flash Storage        Intel HD Graphics 6000  macOS
# 3           8GB            256GB SSD         Intel HD Graphics 620  No OS
# 4          16GB            512GB SSD            AMD Radeon Pro 455  macOS
# 5           8GB            256GB SSD  Intel Iris Plus Graphics 650  macOS
#
#            Weight  Price_euros
# laptop_ID
# 1          1.37kg      1339.69
# 2          1.34kg       898.94
# 3          1.86kg       575.00
# 4          1.83kg      2537.45
# 5          1.37kg      1803.60

# %% [markdown]
# ## Задание 2.
# Проведите первичный анализ данных
# 1. Изучите типы данных
# 2. Найдите количество пропущенных ячеек в данных
# 3. Посчитайте основные статистики по всем признакам и поизучайте их

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1303 entries, 1 to 1320
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1295 non-null   object
#  1   Product           1295 non-null   object
#  2   TypeName          1295 non-null   object
#  3   Inches            1295 non-null   float64
#  4   ScreenResolution  1295 non-null   object
#  5   Cpu               1295 non-null   object
#  6   Ram               1295 non-null   object
#  7   Memory            1295 non-null   object
#  8   Gpu               1295 non-null   object
#  9   OpSys             1295 non-null   object
#  10  Weight            1295 non-null   object
#  11  Price_euros       1295 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 132.3+ KB

# %%
df.isna()
# Out:
#            Company  Product  TypeName  Inches  ScreenResolution    Cpu    Ram  \
# laptop_ID
# 1            False    False     False   False             False  False  False
# 2            False    False     False   False             False  False  False
# 3            False    False     False   False             False  False  False
# 4            False    False     False   False             False  False  False
# 5            False    False     False   False             False  False  False
# ...            ...      ...       ...     ...               ...    ...    ...
# 1316         False    False     False   False             False  False  False
# 1317         False    False     False   False             False  False  False
# 1318         False    False     False   False             False  False  False
# 1319         False    False     False   False             False  False  False
# 1320         False    False     False   False             False  False  False
#
#            Memory    Gpu  OpSys  Weight  Price_euros
# laptop_ID
# 1           False  False  False   False        False
# 2           False  False  False   False        False
# 3           False  False  False   False        False
# 4           False  False  False   False        False
# 5           False  False  False   False        False
# ...           ...    ...    ...     ...          ...
# 1316        False  False  False   False        False
# 1317        False  False  False   False        False
# 1318        False  False  False   False        False
# 1319        False  False  False   False        False
# 1320        False  False  False   False        False
#
# [1303 rows x 12 columns]

# %%
df.describe()
# Out:
#             Inches  Price_euros
# count  1295.000000  1295.000000
# mean     15.030270  1124.317266
# std       1.415632   700.193254
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1489.495000
# max      18.400000  6099.000000

# %%
df.describe(include=['object'])
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1295    1295      1295               1295
# unique      19     615         6                 39
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       725                505
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1295  1295       1295                   1295
# unique                         113     9         38                    109
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   613        411                    281
#
#              OpSys Weight
# count         1295   1295
# unique           9    176
# top     Windows 10  2.2kg
# freq          1070    121

# %% [markdown]
# ## Задание 3.
# Ответьте на несколько вопросов
# ### 3.1 Ноутбуков от какой компании больше всего в наборе
# данных?

# %%
df_company = df['Company'].value_counts() 
df_company
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         15
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Chuwi          1
# Name: count, dtype: int64

# %%
df_company[df_company == df_company.max()]
# Out:
# Company
# Dell      297
# Lenovo    297
# Name: count, dtype: int64

# %% [markdown]
# ### 3.2 Какая минимальная и максимальная стоимость у ноутбуков в данных?

# %%
df['Price_euros'].max()
# Out:
# 6099.0

# %%
df['Price_euros'].min()
# Out:
# 174.0

# %% [markdown]
# ### 3.3 Какой самый дорогой ноутбук в данных?
# Выведите все характеристики только по этому ноутбуку
# Если таких ноутбуков несколько, то выводите их всех

# %%
df[df['Price_euros'] == df['Price_euros'].max()]
# Out:
#           Company    Product TypeName  Inches  \
# laptop_ID
# 200         Razer  Blade Pro   Gaming    17.3
#
#                               ScreenResolution                          Cpu  \
# laptop_ID
# 200        4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz
#
#             Ram   Memory                      Gpu       OpSys  Weight  \
# laptop_ID
# 200        32GB  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg
#
#            Price_euros
# laptop_ID
# 200             6099.0

# %% [markdown]
# ## Задание 4.
# Ответьте на несколько вопросов
# ### 4.1 Найдите ноутбуки с самой маленькой диагональю в данных?
# Выведите только следующие характеристики:
# 1. Компания
# 2. Типа ноутбука
# 3. Диагональ
# 4. Стоимость
# Если таких ноутбуков несколько, то выводите их всех

# %%
df[df['Inches'] == df['Inches'].min()][['Company','TypeName', 'Inches']]
# Out:
#           Company            TypeName  Inches
# laptop_ID
# 51         Lenovo  2 in 1 Convertible    10.1
# 1097       Lenovo  2 in 1 Convertible    10.1
# 1129       Lenovo  2 in 1 Convertible    10.1
# 1141       Lenovo  2 in 1 Convertible    10.1

# %% [markdown]
# ### 4.2 Сколько стоит самый дорогой ноутбук у компании HP?

# %%
df[df['Company'] == 'HP'][['Price_euros']].max()
# Out:
# Price_euros    4389.0
# dtype: float64

# %%
df.loc[df['Company'] == 'HP', 'Price_euros'].max()
# Out:
# 4389.0

# %% [markdown]
# ### 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении
# относительно всех ультрабуков

# %%
df_ultra = df[(df['TypeName'] == 'Ultrabook') & (df['Ram'] == '8GB')]
df_ultra
# Out:
#           Company               Product   TypeName  Inches  \
# laptop_ID
# 1           Apple           MacBook Pro  Ultrabook    13.3
# 2           Apple           Macbook Air  Ultrabook    13.3
# 5           Apple           MacBook Pro  Ultrabook    13.3
# 8           Apple           Macbook Air  Ultrabook    13.3
# 10           Acer               Swift 3  Ultrabook    14.0
# ...           ...                   ...        ...     ...
# 1254           HP         EliteBook 840  Ultrabook    14.0
# 1259         Asus  ZenBook UX310UA-WB71  Ultrabook    13.3
# 1279         Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1293         Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1307         Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 5          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
# 8                                    1440x900        Intel Core i5 1.8GHz
# 10                IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# ...                                       ...                         ...
# 1254                                2560x1440  Intel Core i7 6500U 2.5GHz
# 1259                        Full HD 1920x1080  Intel Core i7 6500U 2.5GHz
# 1279              IPS Panel Full HD 1920x1080    Intel Core M 6Y30 0.9GHz
# 1293              IPS Panel Full HD 1920x1080    Intel Core M 6Y30 0.9GHz
# 1307              IPS Panel Full HD 1920x1080    Intel Core M 6Y30 0.9GHz
#
#            Ram               Memory                           Gpu       OpSys  \
# laptop_ID
# 1          8GB            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 2          8GB  128GB Flash Storage        Intel HD Graphics 6000       macOS
# 5          8GB            256GB SSD  Intel Iris Plus Graphics 650       macOS
# 8          8GB  256GB Flash Storage        Intel HD Graphics 6000       macOS
# 10         8GB            256GB SSD        Intel UHD Graphics 620  Windows 10
# ...        ...                  ...                           ...         ...
# 1254       8GB            256GB SSD         Intel HD Graphics 520   Windows 7
# 1259       8GB            256GB SSD         Intel HD Graphics 520  Windows 10
# 1279       8GB            512GB SSD         Intel HD Graphics 515  Windows 10
# 1293       8GB            512GB SSD         Intel HD Graphics 515  Windows 10
# 1307       8GB            512GB SSD         Intel HD Graphics 515  Windows 10
#
#            Weight  Price_euros
# laptop_ID
# 1          1.37kg      1339.69
# 2          1.34kg       898.94
# 5          1.37kg      1803.60
# 8          1.34kg      1158.70
# 10          1.6kg       770.00
# ...           ...          ...
# 1254       1.54kg      2198.19
# 1259       1.45kg      1280.00
# 1279        1.2kg       729.00
# 1293        1.2kg       729.00
# 1307        1.2kg       729.00
#
# [134 rows x 12 columns]

# %%
df_ultra.count()
# Out:
# Company             134
# Product             134
# TypeName            134
# Inches              134
# ScreenResolution    134
# Cpu                 134
# Ram                 134
# Memory              134
# Gpu                 134
# OpSys               134
# Weight              134
# Price_euros         134
# dtype: int64

# %%
df_ultra.shape[0]
# Out:
# 134

# %%
df_ultrabook = df[df['TypeName'] == 'Ultrabook']
df_ultrabook.shape[0]
# Out:
# 190

# %%
percentage = round(df_ultra.shape[0] / df_ultrabook.shape[0] * 100, 2)
percentage
# Out:
# 70.53

# %%
df_ultrabook.value_counts('Ram', normalize=True).loc['8GB'].round(4)*100
# Out:
# 70.53

# %% [markdown]
# ## Задание 5.
# ### 5.1 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в
# стоимости до 500 евро, сколько у него вариантов?

# %%
choice_1 = df[((df['Ram'] == '8GB') | (df['Ram'] == '16GB')) & (df['OpSys'] == 'Windows 10') & (df['Price_euros'] < 500)]
choice_1
# Out:
#           Company                                   Product  TypeName  Inches  \
# laptop_ID
# 76           Acer                             Aspire E5-475  Notebook    14.0
# 179          Dell                             Inspiron 3567  Notebook    15.6
# 261            HP        15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook    15.6
# 297            HP         17-BS037cl (i3-6006U/8GB/1TB/W10)  Notebook    17.3
# 318          Acer  ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook    15.6
# 371            HP            15-AY023na (N3710/8GB/2TB/W10)  Notebook    15.6
# 578            HP            14-am079na (N3710/8GB/2TB/W10)  Notebook    14.0
# 602        Lenovo                         IdeaPad 110-15ISK  Notebook    15.6
# 642          Asus         X541NA-GO414T (N3350/8GB/1TB/W10)  Notebook    15.6
# 710        Lenovo                         IdeaPad 320-15ABR  Notebook    15.6
# 1071         Acer                            Aspire ES1-523  Notebook    15.6
# 1181       Lenovo                         IdeaPad 310-15ISK  Notebook    15.6
# 1250         Dell                             Inspiron 3567  Notebook    15.6
#
#                ScreenResolution                                   Cpu  Ram  \
# laptop_ID
# 76                     1366x768              Intel Core i3 6006U 2GHz  8GB
# 179                    1366x768            Intel Core i3 7100U 2.4GHz  8GB
# 261                    1366x768          AMD A6-Series A6-9220 2.5GHz  8GB
# 297                    1600x900              Intel Core i3 6006U 2GHz  8GB
# 318           Full HD 1920x1080             AMD A8-Series 7410 2.2GHz  8GB
# 371                    1366x768  Intel Pentium Quad Core N3710 1.6GHz  8GB
# 578                    1366x768  Intel Pentium Quad Core N3710 1.6GHz  8GB
# 602                    1366x768            Intel Core i3 6100U 2.3GHz  8GB
# 642                    1366x768  Intel Celeron Dual Core N3350 1.1GHz  8GB
# 710                    1366x768           AMD A12-Series 9720P 3.6GHz  8GB
# 1071                   1366x768             AMD A8-Series 7410 2.2GHz  8GB
# 1181                   1366x768            Intel Core i3 6006U 2.0GHz  8GB
# 1250       Touchscreen 1366x768            Intel Core i3 7100U 2.4GHz  8GB
#
#               Memory                     Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 76           1TB HDD   Intel HD Graphics 520  Windows 10   2.1kg       389.00
# 179          1TB HDD   Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 261        128GB SSD  AMD Radeon R4 Graphics  Windows 10  1.91kg       445.90
# 297          1TB HDD   Intel HD Graphics 520  Windows 10  2.54kg       489.00
# 318        256GB SSD           AMD Radeon R5  Windows 10  2.23kg       469.00
# 371          2TB HDD   Intel HD Graphics 405  Windows 10  2.04kg       389.00
# 578          2TB HDD   Intel HD Graphics 405  Windows 10  1.94kg       389.00
# 602          1TB HDD   Intel HD Graphics 520  Windows 10  2.29kg       459.00
# 642          1TB HDD   Intel HD Graphics 500  Windows 10     2kg       399.00
# 710          1TB HDD           AMD Radeon R7  Windows 10   2.2kg       429.00
# 1071         1TB HDD           AMD Radeon R5  Windows 10   2.4kg       449.00
# 1181         1TB HDD   Intel HD Graphics 520  Windows 10   2.2kg       459.00
# 1250         1TB HDD   Intel HD Graphics 620  Windows 10   2.3kg       469.01

# %%
choice_1.shape[0]
# Out:
# 13

# %%
choice_1 = df[(df['Ram'].isin(['8GB', '16GB'])) & (df['OpSys'] == 'Windows 10') & (df['Price_euros'] < 500)].shape[0]
choice_1
# Out:
# 13

# %% [markdown]
# ### 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX
# 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли
# подобные ноутбуки?

# %%
choice_2 = df[(df['Company'] == 'MSI') & (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') & (df['Inches'] != 15.6)]
choice_2['Price_euros'].min(), choice_2['Price_euros'].max()
# Out:
# (1199.0, 1599.0)

# %% [markdown]
# ### 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel
# Core i7 7600U 2.8GHz?

# %%
price_1 = df[df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz']['Price_euros'].mean().round(2)
price_1
# Out:
# 1760.41

# %%
price_2 = df[df['Cpu'] == 'Intel Core i7 7600U 2.8GHz']['Price_euros'].mean().round(2)
price_2
# Out:
# 1915.71

# %% [markdown]
# ## Задание 6.
# Найдите самый легкий ноутбук
# Но обратите внимание на тип и представление данных в признаке
# Weight, если что, замените в строке 'kg' на пустую строку через
# метод .str.replace()

# %%
df.head()
# Out:
#           Company      Product   TypeName  Inches  \
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3
# 2           Apple  Macbook Air  Ultrabook    13.3
# 3              HP       250 G6   Notebook    15.6
# 4           Apple  MacBook Pro  Ultrabook    15.4
# 5           Apple  MacBook Pro  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 3                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 4          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 5          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
#
#             Ram               Memory                           Gpu  OpSys  \
# laptop_ID
# 1           8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS
# 2           8GB  128GB Flash Storage        Intel HD Graphics 6000  macOS
# 3           8GB            256GB SSD         Intel HD Graphics 620  No OS
# 4          16GB            512GB SSD            AMD Radeon Pro 455  macOS
# 5           8GB            256GB SSD  Intel Iris Plus Graphics 650  macOS
#
#            Weight  Price_euros
# laptop_ID
# 1          1.37kg      1339.69
# 2          1.34kg       898.94
# 3          1.86kg       575.00
# 4          1.83kg      2537.45
# 5          1.37kg      1803.60

# %%
df['Weight'] = df['Weight'].str.replace('kg', '').astype('float')

# %%
df.head()
# Out:
#           Company      Product   TypeName  Inches  \
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3
# 2           Apple  Macbook Air  Ultrabook    13.3
# 3              HP       250 G6   Notebook    15.6
# 4           Apple  MacBook Pro  Ultrabook    15.4
# 5           Apple  MacBook Pro  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 3                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 4          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 5          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
#
#             Ram               Memory                           Gpu  OpSys  \
# laptop_ID
# 1           8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS
# 2           8GB  128GB Flash Storage        Intel HD Graphics 6000  macOS
# 3           8GB            256GB SSD         Intel HD Graphics 620  No OS
# 4          16GB            512GB SSD            AMD Radeon Pro 455  macOS
# 5           8GB            256GB SSD  Intel Iris Plus Graphics 650  macOS
#
#            Weight  Price_euros
# laptop_ID
# 1            1.37      1339.69
# 2            1.34       898.94
# 3            1.86       575.00
# 4            1.83      2537.45
# 5            1.37      1803.60

# %%
df['Weight'].min()
# Out:
# 0.69

# %%
df.sort_values('Weight')
# Out:
#                                                     Company     Product  \
# laptop_ID
# 51                                                   Lenovo   Yoga Book
# 1141                                                 Lenovo   Yoga Book
# 1097                                                 Lenovo   Yoga Book
# 1129                                                 Lenovo   Yoga Book
# 821                                                 Samsung  Notebook 9
# ...                                                     ...         ...
# 490,Chuwi,"Lapbook 15,6",Notebook,15.6,Full HD ...      NaN         NaN
# 803,Apple,"MacBook 12""",Ultrabook,12,IPS Panel...      NaN         NaN
# 1084,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...      NaN         NaN
# 1211,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...      NaN         NaN
# 1228,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...      NaN         NaN
#
#                                                               TypeName  \
# laptop_ID
# 51                                                  2 in 1 Convertible
# 1141                                                2 in 1 Convertible
# 1097                                                2 in 1 Convertible
# 1129                                                2 in 1 Convertible
# 821                                                          Ultrabook
# ...                                                                ...
# 490,Chuwi,"Lapbook 15,6",Notebook,15.6,Full HD ...                 NaN
# 803,Apple,"MacBook 12""",Ultrabook,12,IPS Panel...                 NaN
# 1084,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                 NaN
# 1211,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                 NaN
# 1228,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                 NaN
#
#                                                     Inches  \
# laptop_ID
# 51                                                    10.1
# 1141                                                  10.1
# 1097                                                  10.1
# 1129                                                  10.1
# 821                                                   13.3
# ...                                                    ...
# 490,Chuwi,"Lapbook 15,6",Notebook,15.6,Full HD ...     NaN
# 803,Apple,"MacBook 12""",Ultrabook,12,IPS Panel...     NaN
# 1084,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...     NaN
# 1211,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...     NaN
# 1228,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...     NaN
#
#                                                                    ScreenResolution  \
# laptop_ID
# 51                                                  IPS Panel Touchscreen 1920x1200
# 1141                                                IPS Panel Touchscreen 1920x1200
# 1097                                                IPS Panel Touchscreen 1920x1200
# 1129                                                IPS Panel Touchscreen 1920x1200
# 821                                                               Full HD 1920x1080
# ...                                                                             ...
# 490,Chuwi,"Lapbook 15,6",Notebook,15.6,Full HD ...                              NaN
# 803,Apple,"MacBook 12""",Ultrabook,12,IPS Panel...                              NaN
# 1084,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                              NaN
# 1211,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                              NaN
# 1228,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                              NaN
#
#                                                                             Cpu  \
# laptop_ID
# 51                                                  Intel Atom x5-Z8550 1.44GHz
# 1141                                                Intel Atom x5-Z8550 1.44GHz
# 1097                                                Intel Atom x5-Z8550 1.44GHz
# 1129                                                Intel Atom x5-Z8550 1.44GHz
# 821                                                  Intel Core i5 7200U 2.5GHz
# ...                                                                         ...
# 490,Chuwi,"Lapbook 15,6",Notebook,15.6,Full HD ...                          NaN
# 803,Apple,"MacBook 12""",Ultrabook,12,IPS Panel...                          NaN
# 1084,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                          NaN
# 1211,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                          NaN
# 1228,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                          NaN
#
#                                                     Ram              Memory  \
# laptop_ID
# 51                                                  4GB  64GB Flash Storage
# 1141                                                4GB  64GB Flash Storage
# 1097                                                4GB  64GB Flash Storage
# 1129                                                4GB  64GB Flash Storage
# 821                                                 8GB           256GB SSD
# ...                                                 ...                 ...
# 490,Chuwi,"Lapbook 15,6",Notebook,15.6,Full HD ...  NaN                 NaN
# 803,Apple,"MacBook 12""",Ultrabook,12,IPS Panel...  NaN                 NaN
# 1084,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...  NaN                 NaN
# 1211,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...  NaN                 NaN
# 1228,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...  NaN                 NaN
#
#                                                                       Gpu  \
# laptop_ID
# 51                                                  Intel HD Graphics 400
# 1141                                                Intel HD Graphics 400
# 1097                                                Intel HD Graphics 400
# 1129                                                Intel HD Graphics 400
# 821                                                 Intel HD Graphics 620
# ...                                                                   ...
# 490,Chuwi,"Lapbook 15,6",Notebook,15.6,Full HD ...                    NaN
# 803,Apple,"MacBook 12""",Ultrabook,12,IPS Panel...                    NaN
# 1084,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                    NaN
# 1211,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                    NaN
# 1228,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...                    NaN
#
#                                                          OpSys  Weight  \
# laptop_ID
# 51                                                     Android    0.69
# 1141                                                Windows 10    0.69
# 1097                                                Windows 10    0.69
# 1129                                                   Android    0.69
# 821                                                 Windows 10    0.81
# ...                                                        ...     ...
# 490,Chuwi,"Lapbook 15,6",Notebook,15.6,Full HD ...         NaN     NaN
# 803,Apple,"MacBook 12""",Ultrabook,12,IPS Panel...         NaN     NaN
# 1084,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...         NaN     NaN
# 1211,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...         NaN     NaN
# 1228,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...         NaN     NaN
#
#                                                     Price_euros
# laptop_ID
# 51                                                       319.00
# 1141                                                     479.00
# 1097                                                     646.27
# 1129                                                     549.00
# 821                                                     1499.00
# ...                                                         ...
# 490,Chuwi,"Lapbook 15,6",Notebook,15.6,Full HD ...          NaN
# 803,Apple,"MacBook 12""",Ultrabook,12,IPS Panel...          NaN
# 1084,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...          NaN
# 1211,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...          NaN
# 1228,Apple,"MacBook 12""",Ultrabook,12,IPS Pane...          NaN
#
# [1303 rows x 12 columns]
